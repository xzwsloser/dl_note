# %% [markdown]
# # 全局向量的词嵌入(GloVe)
# ## 带全局语料统计的跳元模型
# 使用$q_{ij}$表示词$w_j$的条件概率$P(w_j \mid w_i)$, 在跳元模型中给定词$w_i$, 可以得到:
# $$
# q_{ij} = \frac {\exp(\mathbf{u}_j^T \mathbf{v}_i)}{\sum_{k \in \mathcal{V}} \exp(\mathbf{u}_k^T \mathbf{v}_i)}
# $$
# 利用全局料库, 对应的跳元模型的损失函数等价于:
# ![image.png](attachment:989b3882-0737-4164-bd68-e7da2050baf2.png)
# 下面公式可以这样理解, $x_i$ 表示 $w_i$ 作为中心词的时候上下文窗口中对应所有词的数量, 同时 $p_{ij}$ 表示 $w_j$ 占比

# %% [markdown]
# ## GloVe模型
# `GloVe`模型基于平方损失对于跳元模型做如下的修改, 从而降低复杂度:
# ![image.png](attachment:7ab1b94a-1539-4c79-aca1-3fb90a3366ab.png)

# %% [markdown]
# ### 从条件概率比值理解 GloVe 模型
# 和传统的跳元模型相比, 其实相当于是在整个语料库中做比较 ; 可以使用这些条件概率来估计共存概率
# ![image.png](attachment:f7976d77-7f17-492c-9756-92d3bb355529.png)
