# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from d2l import torch as d2l

# %% [markdown]
# # 卷积神经网络
# 前面已经学习了卷积神经网络中的各种组件, 这里以最早的神经网络之一的 `LeNet` 来介绍一下卷积层和汇聚层的基本使用

# %% [markdown]
# ## LeNet
# `LeNet`由两个部分组成:
# - 卷积编码器: 由两个卷积层组成
# - 全连接层密集块: 由三个全连接层组成
# 网络架构如下:
# ![image.png](attachment:5d834d21-786f-4917-82d6-3606d11eeace.png)
# 注意整个过程中的维度变换的计算方法, 同时注意到输入到全连接层的时候首先需要展开所有数据

# %%
# 1. 定义网络结构
# 输入数据 (n, 1, 28, 28)
net = nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Sigmoid(), # 保证图片大小不变
    nn.AvgPool2d(kernel_size=2, stride=2), # 利用汇聚层聚合一次数据
    nn.Conv2d(6, 16, kernel_size=5), nn.Sigmoid(), # 再进行一次卷积
    nn.AvgPool2d(kernel_size=2, stride=2),
    nn.Flatten(), # 展开, 此时需要保证数据大小为 n * d (批次大小 * 特征数)
    nn.Linear(16 * 5 * 5, 120), nn.Sigmoid(), # 此时需要融合所有特征
    nn.Linear(120, 84), nn.Sigmoid(),
    nn.Linear(84, 10)
)

# %% [markdown]
# 此时输入图像为大小为 $28 \times 28$ 的单通道(黑白)图像, 整个过程如下:
# ![image.png](attachment:2df4c93c-bb4a-4c69-bed0-446f8c089004.png)

# %%
# 检查每一层形状
X = torch.rand(size=(1, 1, 28, 28), dtype=torch.float32)
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__, 'output shape: \t', X.shape)
# Out:
# Conv2d output shape: 	 torch.Size([1, 6, 28, 28])
# Sigmoid output shape: 	 torch.Size([1, 6, 28, 28])
# AvgPool2d output shape: 	 torch.Size([1, 6, 14, 14])
# Conv2d output shape: 	 torch.Size([1, 16, 10, 10])
# Sigmoid output shape: 	 torch.Size([1, 16, 10, 10])
# AvgPool2d output shape: 	 torch.Size([1, 16, 5, 5])
# Flatten output shape: 	 torch.Size([1, 400])
# Linear output shape: 	 torch.Size([1, 120])
# Sigmoid output shape: 	 torch.Size([1, 120])
# Linear output shape: 	 torch.Size([1, 84])
# Sigmoid output shape: 	 torch.Size([1, 84])
# Linear output shape: 	 torch.Size([1, 10])

# %% [markdown]
# ## 模型训练

# %%
batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size=batch_size)
# Out:
# ...
# 100.0%
# Extracting ../data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ../data/FashionMNIST/raw
#
# ...
# 100.0%
# Extracting ../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw
#
# ...
# 100.0%
# Extracting ../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ../data/FashionMNIST/raw
#
# ...
# 100.0%
# Extracting ../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw

# %%
# 使用 GPU 训练模型
def train_ch6(net, train_iter, test_iter, num_epochs, lr, device):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    net.apply(init_weights)
    print('train on', device)
    net.to(device)
    optimizer = torch.optim.SGD(net.parameters(), lr=lr)
    loss = nn.CrossEntropyLoss()
    animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs], 
                           legend=['train loss', 'train loss', 'test acc'])
    timer, num_batches = d2l.Timer(),len(train_iter)
    for epoch in range(num_epochs):
        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            timer.start()
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            timer.stop()
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
            if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
                animator.add(epoch + (i + 1)/num_batches,
                             (train_l, train_acc, None))
        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        animator.add(epoch + 1, (None, None, test_acc))
    print(f'loss {train_l:.3f}, train acc {train_acc:.3f}, '
          f'test acc {test_acc:.3f}')
    print(f'{metric[2] * num_epochs / timer.sum():.1f} examples/sec '
          f'on {str(device)}')

# %%
# 确定设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
lr, num_epochs = 0.9, 10
train_ch6(net, train_iter, test_iter, num_epochs, lr, device)
# Out:
# loss 0.463, train acc 0.828, test acc 0.759
# 18188.9 examples/sec on cpu
